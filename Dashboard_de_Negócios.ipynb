# %% [markdown]
# <a href="https://colab.research.google.com/github/Nina-Fonseca/Meus-estudos/blob/main/Dashboard_de_Neg%C3%B3cios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cotação do Dólar
#
# Para esse exercício tenho como problema a Cotação do Dólar e trouxe uma visualização dos dados.
#
# Usei o dataset público do Banco Central do Brasil e tenho como objetivo acompanhar a cotação do dólar. O dashboard apresentado conta com as seguintes informações:
#
#
#
# 1.   Cotação do Dólar atual
#
# 2.   Variação do Dólar
#
# 3.   Cotação do Dólar diário
#
# 4.   Cotação anual
#
# 5.   Análise em tempo real
#
# Esse tipo de visualização é muito útil para empresas ou pessoas que fazem negócios no exterior.
#
#
# ![Projeto Power BI.png](data:image/png;base64,...)
